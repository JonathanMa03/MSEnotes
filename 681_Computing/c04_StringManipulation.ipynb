# %% [markdown]
# ## 04: String Manipulation
# ### Section 7.2-8.1

# %% [markdown]
# #### Reading and writing files

# %%
# loading a file from base
import os
folder=os.getcwd()
print(folder)

# Method 1: file name from cwd
fileid="testdoc.txt"
# Method 2: Relative path (file above)
fileid="../testdoc.txt"
# Method 3: absolute path
fileid="/Users/jonathanma/Desktop/MSE AMS/688_computingAM/testdoc.txt"

fin=open(fileid)
text=fin.read()
fin.close()
print(text)
# Out:
# /Users/jonathanma/Desktop/MSE AMS/688_computingAM
# i am a cat
# i am a fox
# i am a catfox

# %%
# to get a hex value for a string
hex(537)
# Out:
# '0x219'

# %%
# read one line at a time
fin=open("testdoc.txt")
while True:
    s=fin.readline()
    if s:
        print(s)
    else:
        break
fin.close()

# with closes the file after running the function
with open("testdoc.txt") as fin:
    for line in fin:
        print(line)
# Out:
# i am a cat
#
# i am a fox
#
# i am a catfox
# i am a cat
#
# i am a fox
#
# i am a catfox

# %%
# remove whitespace
fin=open("testdoc.txt")
while True:
    s=fin.readline()
    if s:
        print(s.strip())
    else:
        break
fin.close()
# Out:
# i am a cat
# i am a fox
# i am a catfox

# %%
# enumerate is helpful to create generator tuples
L=["apple","orange","banana","tangerine"]
E=enumerate(L)
print(next(E))
print(next(E))
print(next(E))
print(next(E))
# Out:
# (0, 'apple')
# (1, 'orange')
# (2, 'banana')
# (3, 'tangerine')

# %%
# we can use enumeration to track line numbers
with open("testdoc.txt") as fin:
    E=enumerate(fin)
    for e in E:
        print(e)
        #if e[1].count("s")>=1:
        #    print(e)
# Out:
# (0, 'i am a cat\n')
# (1, 'i am a fox\n')
# (2, 'i am a catfox')

# %%
# writing to a file
with open("output.txt","w") as fout:
    text="This is some text."
    fout.write(text+"\n")
    text="And some more."
    fout.write(text)

with open("output.txt") as fin:
    text=fin.read()
print(text)
# Out:
# This is some text.
# And some more.

# %% [markdown]
# #### Bytes, Byte Strings, and Binaries

# %%
# we can create an int using hexadecimal prefix
x=0xf1
print(type(x))
print(x)

# or by using a binary prefix
y=0b10110110101010111
print(type(y))
print(y)
# Out:
# <class 'int'>
# 241
# <class 'int'>
# 93527

# %%
#we can convert from string hex or string binary to int, but need to specify base
x="0xFFA2"
print(type(x))
print(len(x))
print(x)
y=int(x,16)
print(type(y))
# Out:
# <class 'str'>
# 6
# 0xFFA2
# <class 'int'>

# %% [markdown]
# #### Formatting Strings

# %%
# here is how we can create dynamic strings
mystring = "Hi, my name is {value} and {value}" 
print(mystring)
newstring=mystring.format(value="Joe")
print(newstring)
print("\n")

# multiple substitutions are allowed
st="My {relationship}'s name is {name}."
nm=["Doris","Paul","Janice","Melvin","Rita"]
rel=["sister","brother","sister","father","mother"]
for i in range(5):
    newstring=st.format(name=nm[i],relationship=rel[i])
    print(newstring)
print("\n")

# and can be repeated many times
mystring = "Did your {pet1} chase your {pet2} or did your {pet2} chase your {pet1}?"
newstring=mystring.format(pet1="dog",pet2="cat")
print(newstring)
# Out:
# Hi, my name is {value} and {value}
# Hi, my name is Joe and Joe
#
#
# My sister's name is Doris.
# My brother's name is Paul.
# My sister's name is Janice.
# My father's name is Melvin.
# My mother's name is Rita.
#
#
# Did your dog chase your cat or did your cat chase your dog?

# %%
# argument names are not required
mystring = "{}, {} and {} were there but {} couldn't make it" 
newstring=mystring.format("John","Paul","George","Ringo")
print(newstring)
print("\n")

# we csn use indices as well
mystring = "He used to bring his {0:} but never his {0:}. I would have preferred his {1:}" 
newstring=mystring.format("dog", "cat","bird")
print(newstring)
# Out:
# John, Paul and George were there but Ringo couldn't make it
#
#
# He used to bring his dog but never his dog. I would have preferred his cat

# %% [markdown]
# #### Formatting Floats

# %%
import math
txt = "The value of pi is {:^20.6f}." # centered
print(txt.format(math.pi))
txt = "The value of  e is {:>30.10f}." # right aligned
print(txt.format(math.e))
txt = "The value of pi is {:<30.10f}." # left aligned
print(txt.format(math.pi))
txt = "The value of  e is {:30.10f}." # default alighnment
print(txt.format(math.e))

# or with ints
amount=123
txt = "I have ${:^10d} in my pocket" # centered and using 10 spaces
print(txt.format(amount))
txt = "I have ${:>10d} in my pocket" # right aligned
print(txt.format(amount))
txt = "I have ${:<10d} in my pocket" # left aligned
print(txt.format(amount))
txt = "I have ${:10d} in my pocket" # default
print(txt.format(amount))
# Out:
# The value of pi is       3.141593      .
# The value of  e is                   2.7182818285.
# The value of pi is 3.1415926536                  .
# The value of  e is                   2.7182818285.
# I have $   123     in my pocket
# I have $       123 in my pocket
# I have $123        in my pocket
# I have $       123 in my pocket

# %%
# signage
txt = "My baby is {:} months old."
print(txt.format(6))
txt = "My baby is {:} months old."
print(txt.format(-6))
txt = "My baby is {:+} months old."
print(txt.format(-6))
print(txt.format(6))
# Out:
# My baby is 6 months old.
# My baby is -6 months old.
# My baby is -6 months old.
# My baby is +6 months old.

# %%
# sig figs
txt = "The speed of light is {:E} km/hr"
print(txt.format( 1079252848.8))
txt = "The speed of light is {:.3E} km/hr"
print(txt.format( 1079252848.8))
txt = "The speed of light is {:.1E} km/hr"
print(txt.format( 1079252848.8))

# commas
txt = "The speed of light is {:} km/hr"
print(txt.format( 1079252848.8))
txt = "The speed of light is {:,} km/hr"
print(txt.format( 1079252848.84389439839))
# Out:
# The speed of light is 1.079253E+09 km/hr
# The speed of light is 1.079E+09 km/hr
# The speed of light is 1.1E+09 km/hr
# The speed of light is 1079252848.8 km/hr
# The speed of light is 1,079,252,848.8438945 km/hr

# %%
# how to create a table
import numpy as np
name=["bob","mary","joe","alice","ted","rose","rita","mel","ed","monique"]
print(name)
balance=[np.round(np.exp(np.random.uniform(0,10)),2) for i in range(10)]
print(balance)
age=np.random.randint(20,80,10)
print(age)
txt="{:10} {:>10} {:>5}"
print(txt.format("Name","Balance","Age"))
txt="{:10} {:10.2f} {:5}"
for i in range(10):
    print(txt.format(name[i],balance[i],age[i]))
# Out:
# ['bob', 'mary', 'joe', 'alice', 'ted', 'rose', 'rita', 'mel', 'ed', 'monique']
# [np.float64(543.7), np.float64(3843.13), np.float64(9.56), np.float64(14468.99), np.float64(1213.74), np.float64(354.34), np.float64(11.37), np.float64(1.13), np.float64(42.89), np.float64(4.22)]
# [39 47 27 67 29 40 70 30 61 35]
# Name          Balance   Age
# bob            543.70    39
# mary          3843.13    47
# joe              9.56    27
# alice        14468.99    67
# ted           1213.74    29
# rose           354.34    40
# rita            11.37    70
# mel              1.13    30
# ed              42.89    61
# monique          4.22    35

# %%
# the new way to d=format: f-string literals
Cities=["Boston","Baltimore", "Philadelphia"]
for city in Cities:
    st=f"{city} has {len(city)} letters"
    print(st)
# Out:
# Boston has 6 letters
# Baltimore has 9 letters
# Philadelphia has 12 letters

# %% [markdown]
# #### Unicode

# %%
# --- Basic exploration of Unicode ---

# 1. Define some sample characters
chars = ['A', 'a', 'é', 'Ω', '中', '😊']

# 2. Show Unicode code points (ord) and names
import unicodedata

for ch in chars:
    code_point = ord(ch)   # Get integer code point
    name = unicodedata.name(ch)   # Get official Unicode name
    print(f"Character: {ch} | Code point: U+{code_point:04X} | Name: {name}")

print("\n--- Encoding to bytes ---")

# 3. Encode characters into UTF-8 bytes
for ch in chars:
    utf8_bytes = ch.encode("utf-8")  # Convert to UTF-8 byte sequence
    print(f"Character: {ch} | UTF-8 bytes: {list(utf8_bytes)}")

print("\n--- Decoding from bytes ---")

# 4. Decode back from bytes to string
sample_bytes = b'\xe4\xb8\xad'  # UTF-8 for "中"
decoded = sample_bytes.decode("utf-8")
print(f"Bytes: {sample_bytes} | Decoded character: {decoded}")
# Out:
# Character: A | Code point: U+0041 | Name: LATIN CAPITAL LETTER A
# Character: a | Code point: U+0061 | Name: LATIN SMALL LETTER A
# Character: é | Code point: U+00E9 | Name: LATIN SMALL LETTER E WITH ACUTE
# Character: Ω | Code point: U+03A9 | Name: GREEK CAPITAL LETTER OMEGA
# Character: 中 | Code point: U+4E2D | Name: CJK UNIFIED IDEOGRAPH-4E2D
# Character: 😊 | Code point: U+1F60A | Name: SMILING FACE WITH SMILING EYES
#
# --- Encoding to bytes ---
# Character: A | UTF-8 bytes: [65]
# Character: a | UTF-8 bytes: [97]
# Character: é | UTF-8 bytes: [195, 169]
# Character: Ω | UTF-8 bytes: [206, 169]
# Character: 中 | UTF-8 bytes: [228, 184, 173]
# Character: 😊 | UTF-8 bytes: [240, 159, 152, 138]
#
# --- Decoding from bytes ---
# Bytes: b'\xe4\xb8\xad' | Decoded character: 中
